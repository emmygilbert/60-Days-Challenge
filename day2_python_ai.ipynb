# %% [markdown]
# <a href="https://colab.research.google.com/github/checkcode01/60-Days-Challenge/blob/main/day2_python_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Human connection is the real workplace technology")
# Out:
# Human connection is the real workplace technology

# %%
text = input("Enter a sentence: ")

cleaned = text.lower().strip()

print("Cleaned text:", cleaned)
# Out:
# Enter a sentence: Human connection is the real workplace technology
# Cleaned text: human connection is the real workplace technology

# %%
text = input("Enter a sentence: ")

words = text.lower().split()

word_count = {}

for word in words:
    word_count[word] = word_count.get(word, 0) + 1

print(word_count)
# Out:
# Enter a sentence: Human connection is the real workplace technology
# {'human': 1, 'connection': 1, 'is': 1, 'the': 1, 'real': 1, 'workplace': 1, 'technology': 1}
